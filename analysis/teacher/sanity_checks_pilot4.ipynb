# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set_theme(style="white", font_scale=2)

# %%
data_folder = "../data/2022-06-04_alvin"
df = pd.read_csv(os.path.join(data_folder, 'data_pilot3.csv'), index_col=[0])
df['total_ex'] = df['heads'] + df['tails']
df['mean'] = df['heads'] / (df['heads'] + df['tails'])
df['trial'] = df['block_type'] + df['trial_num'].apply(lambda x: str(x))
df.loc[(df['student_class'] == 'A') | (
    df['student_class'] == 'B'), 'student_experience'] = 'less'
df.loc[(df['student_class'] == 'C') | (
    df['student_class'] == 'D'), 'student_experience'] = 'more'
df['theta'] = df['true_theta'] # for plotting purposes
df
# Out:
#       subject_id  student_idx     block_type  trial_num  true_theta  \
# 0   0drjbtj8pl35            0  nonSeqPartial          0         0.5
# 1   0drjbtj8pl35            1  nonSeqPartial          0         0.2
# 2   0drjbtj8pl35            2     nonSeqFull          0         0.2
# 3   0drjbtj8pl35            2     nonSeqFull          0         0.2
# 4   0drjbtj8pl35            2     nonSeqFull          0         0.2
# 5   0drjbtj8pl35            2     nonSeqFull          0         0.2
# 6   0drjbtj8pl35            2     nonSeqFull          0         0.2
# 7   0drjbtj8pl35            3  seqNoFeedback          0         0.5
# 8   0drjbtj8pl35            3  seqNoFeedback          1         0.5
# 9   0drjbtj8pl35            4  seqNoFeedback          0         0.5
# 10  0drjbtj8pl35            4  seqNoFeedback          1         0.5
# 11  0drjbtj8pl35            5    seqFeedback          0         0.2
# 12  0drjbtj8pl35            5    seqFeedback          1         0.2
# 13  0drjbtj8pl35            6     nonSeqFull          0         0.2
# 14  0drjbtj8pl35            6     nonSeqFull          0         0.2
# 15  0drjbtj8pl35            7    seqFeedback          0         0.8
# 16  0drjbtj8pl35            7    seqFeedback          1         0.8
# 17  0drjbtj8pl35            8     nonSeqFull          0         0.8
# 18  0drjbtj8pl35            9  nonSeqPartial          0         0.8
# 19  0drjbtj8pl35           10  nonSeqPartial          0         0.8
# 20  0drjbtj8pl35           11  seqNoFeedback          0         0.2
# 21  0drjbtj8pl35           11  seqNoFeedback          1         0.2
# 22  0drjbtj8pl35           12  seqNoFeedback          0         0.8
# 23  0drjbtj8pl35           12  seqNoFeedback          1         0.8
# 24  0drjbtj8pl35           13    seqFeedback          0         0.5
# 25  0drjbtj8pl35           13    seqFeedback          1         0.5
# 26  0drjbtj8pl35           14    seqFeedback          0         0.8
# 27  0drjbtj8pl35           14    seqFeedback          1         0.8
# 28  0drjbtj8pl35           15  seqNoFeedback          0         0.8
# 29  0drjbtj8pl35           15  seqNoFeedback          1         0.8
# 30  0drjbtj8pl35           16     nonSeqFull          0         0.8
# 31  0drjbtj8pl35           16     nonSeqFull          0         0.8
# 32  0drjbtj8pl35           17     nonSeqFull          0         0.5
# 33  0drjbtj8pl35           18  nonSeqPartial          0         0.5
# 34  0drjbtj8pl35           19  seqNoFeedback          0         0.2
# 35  0drjbtj8pl35           19  seqNoFeedback          1         0.2
# 36  0drjbtj8pl35           20     nonSeqFull          0         0.5
# 37  0drjbtj8pl35           21    seqFeedback          0         0.5
# 38  0drjbtj8pl35           21    seqFeedback          1         0.5
# 39  0drjbtj8pl35           22    seqFeedback          0         0.2
# 40  0drjbtj8pl35           22    seqFeedback          1         0.2
# 41  0drjbtj8pl35           23  nonSeqPartial          0         0.2
#
#     student_a  student_b student_class  heads  tails  student_guess  error  \
# 0           4          1             B      5      5           0.60   0.10
# 1           4          1             B      0      8           0.31   0.11
# 2           1          4             A      0      0           0.20   0.00
# 3           1          4             A      0      0           0.20   0.00
# 4           1          4             A      0      0           0.20   0.00
# 5           1          4             A      0      0           0.20   0.00
# 6           1          4             A      1      4           0.20   0.00
# 7           8          2             D     10     10            NaN    NaN
# 8           8          2             D      5      5           0.57   0.07
# 9           4          1             B      8      2            NaN    NaN
# 10          4          1             B      2      8           0.56   0.06
# 11          2          8             C      0     15           0.08    NaN
# 12          2          8             C      2      7           0.12   0.08
# 13          2          8             C      0      0           0.20   0.00
# 14          2          8             C      1      4           0.20   0.00
# 15          2          8             C     10      0           0.60    NaN
# 16          2          8             C     10      0           0.73   0.07
# 17          2          8             C     30      0           0.80   0.00
# 18          8          2             D     15      0           0.92   0.12
# 19          4          1             B     14      0           0.95   0.15
# 20          4          1             B      0      5            NaN    NaN
# 21          4          1             B      2      8           0.30   0.10
# 22          4          1             B     10      0            NaN    NaN
# 23          4          1             B     16      4           0.86   0.06
# 24          4          1             B      4      1           0.80    NaN
# 25          4          1             B      2      8           0.50   0.00
# 26          1          4             A      9      1           0.67    NaN
# 27          1          4             A      5      0           0.75   0.05
# 28          2          8             C     20      0            NaN    NaN
# 29          2          8             C      7      3           0.72   0.08
# 30          4          1             B      0      0           0.80   0.00
# 31          4          1             B      4      1           0.80   0.00
# 32          4          1             B      1      4           0.50   0.00
# 33          2          8             C     20     20           0.44   0.06
# 34          8          2             D      0      4            NaN    NaN
# 35          8          2             D      0      4           0.44   0.24
# 36          8          2             D      2      8           0.50   0.00
# 37          2          8             C      1      4           0.20    NaN
# 38          2          8             C     12      3           0.50   0.00
# 39          4          1             B      0      4           0.44    NaN
# 40          4          1             B      0     11           0.20   0.00
# 41          8          2             D      1      4           0.60   0.40
#
#     bonus  total_bonus understood  total_ex      mean           trial  \
# 0    0.00         7.85        yes        10  0.500000  nonSeqPartial0
# 1    0.00         7.85        yes         8  0.000000  nonSeqPartial0
# 2    0.50         7.85        yes         0       NaN     nonSeqFull0
# 3    0.50         7.85        yes         0       NaN     nonSeqFull0
# 4    0.50         7.85        yes         0       NaN     nonSeqFull0
# 5    0.50         7.85        yes         0       NaN     nonSeqFull0
# 6    0.45         7.85        yes         5  0.200000     nonSeqFull0
# 7     NaN         7.85        yes        20  0.500000  seqNoFeedback0
# 8    0.20         7.85        yes        10  0.500000  seqNoFeedback1
# 9     NaN         7.85        yes        10  0.800000  seqNoFeedback0
# 10   0.30         7.85        yes        10  0.200000  seqNoFeedback1
# 11    NaN         7.85        yes        15  0.000000    seqFeedback0
# 12   0.00         7.85        yes         9  0.222222    seqFeedback1
# 13   0.50         7.85        yes         0       NaN     nonSeqFull0
# 14   0.45         7.85        yes         5  0.200000     nonSeqFull0
# 15    NaN         7.85        yes        10  1.000000    seqFeedback0
# 16   0.30         7.85        yes        10  1.000000    seqFeedback1
# 17   0.20         7.85        yes        30  1.000000     nonSeqFull0
# 18   0.00         7.85        yes        15  1.000000  nonSeqPartial0
# 19   0.00         7.85        yes        14  1.000000  nonSeqPartial0
# 20    NaN         7.85        yes         5  0.000000  seqNoFeedback0
# 21   0.00         7.85        yes        10  0.200000  seqNoFeedback1
# 22    NaN         7.85        yes        10  1.000000  seqNoFeedback0
# 23   0.20         7.85        yes        20  0.800000  seqNoFeedback1
# 24    NaN         7.85        yes         5  0.800000    seqFeedback0
# 25   0.35         7.85        yes        10  0.200000    seqFeedback1
# 26    NaN         7.85        yes        10  0.900000    seqFeedback0
# 27   0.35         7.85        yes         5  1.000000    seqFeedback1
# 28    NaN         7.85        yes        20  1.000000  seqNoFeedback0
# 29   0.00         7.85        yes        10  0.700000  seqNoFeedback1
# 30   0.50         7.85        yes         0       NaN     nonSeqFull0
# 31   0.45         7.85        yes         5  0.800000     nonSeqFull0
# 32   0.45         7.85        yes         5  0.200000     nonSeqFull0
# 33   0.10         7.85        yes        40  0.500000  nonSeqPartial0
# 34    NaN         7.85        yes         4  0.000000  seqNoFeedback0
# 35   0.00         7.85        yes         4  0.000000  seqNoFeedback1
# 36   0.40         7.85        yes        10  0.200000     nonSeqFull0
# 37    NaN         7.85        yes         5  0.200000    seqFeedback0
# 38   0.30         7.85        yes        15  0.800000    seqFeedback1
# 39    NaN         7.85        yes         4  0.000000    seqFeedback0
# 40   0.35         7.85        yes        11  0.000000    seqFeedback1
# 41   0.00         7.85        yes         5  0.200000  nonSeqPartial0
#
#    student_experience  theta
# 0                less    0.5
# 1                less    0.2
# 2                less    0.2
# 3                less    0.2
# 4                less    0.2
# 5                less    0.2
# 6                less    0.2
# 7                more    0.5
# 8                more    0.5
# 9                less    0.5
# 10               less    0.5
# 11               more    0.2
# 12               more    0.2
# 13               more    0.2
# 14               more    0.2
# 15               more    0.8
# 16               more    0.8
# 17               more    0.8
# 18               more    0.8
# 19               less    0.8
# 20               less    0.2
# 21               less    0.2
# 22               less    0.8
# 23               less    0.8
# 24               less    0.5
# 25               less    0.5
# 26               less    0.8
# 27               less    0.8
# 28               more    0.8
# 29               more    0.8
# 30               less    0.8
# 31               less    0.8
# 32               less    0.5
# 33               more    0.5
# 34               more    0.2
# 35               more    0.2
# 36               more    0.5
# 37               more    0.5
# 38               more    0.5
# 39               less    0.2
# 40               less    0.2
# 41               more    0.2

# %%
len(pd.unique(df['subject_id']))
# Out:
# 118

# %% [markdown]
# Exclusion criteria:
# - did not understand instructions
# - bonus less than `$1`

# %%
df = df[(df['understood'] == 'yes') & (df['total_bonus'] > 1)]
len(pd.unique(df['subject_id']))
# Out:
# 103

# %% [markdown]
# Check performance of four different conditions

# %%
f, ax = plt.subplots(figsize=(8, 5))
sns.barplot(data=df, x='block_type', y='bonus')
sns.stripplot(data=df, x='block_type', y='bonus', color='black', alpha=0.1)
ax.set(ylabel='end-of-trial bonus ($)', xlabel='condition')
sns.despine()

# %%
class_hypers = {
    'A': "($a=1$, $b=4$)",
    'B': "($a=4$, $b=1$)",
    'C': "($a=2$, $b=8$)",
    'D': "($a=8$, $b=2$)"
}

for class_id, hypers in class_hypers.items():
    g = sns.catplot(data=df[(df['student_class'] == class_id)], x='trial_num',
                    y='mean', hue='theta', col='block_type', kind='point', dodge=True,
                    col_order=['nonSeqFull', 'nonSeqPartial', 'seqNoFeedback', 'seqFeedback'], aspect=0.8)
    (g.set_axis_labels("trial num")
     .set_titles("{col_name}")
     .set(ylim=(0, 1.1))
     .figure.suptitle("data " + hypers + " proportion heads", y=1.1, size=30)
     )

    plt.savefig(f"./output/pilot3_{class_id}_means_data.png", dpi=300, bbox_inches='tight')


    g = sns.catplot(data=df[(df['student_class'] == class_id)], x='trial_num',
                    y='total_ex', hue='theta', col='block_type', kind='point', dodge=True,
                    col_order=['nonSeqFull', 'nonSeqPartial', 'seqNoFeedback', 'seqFeedback'], aspect=0.8)
    (g.set_axis_labels("trial num", "total # examples")
    .set(ylim=(0, 25))
     .set_titles("{col_name}")
     .figure.suptitle("data " + hypers + " total # examples", y=1.1, size=30)
     )

    plt.savefig(f"./output/pilot3_{class_id}_total_ex_data.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# Look at the actual points

# %%
class_hypers = {
    'A': "($a=1$, $b=4$)",
    'B': "($a=4$, $b=1$)",
    'C': "($a=8$, $b=2$)",
    'D': "($a=2$, $b=8$)"
}

for class_id, hypers in class_hypers.items():
    g = sns.catplot(data=df[(df['student_class'] == class_id)], x='trial_num',
                    y='mean', hue='theta', col='block_type', dodge=True,
                    col_order=['nonSeqFull', 'nonSeqPartial', 'seqNoFeedback', 'seqFeedback'], alpha=0.5)
    (g.set_axis_labels("trial num")
     .set_titles("{col_name}")
     .set(ylim=(0, 1.1))
     .figure.suptitle(hypers + " proportion heads in examples", y=1.1, size=30)
     )

    g = sns.catplot(data=df[(df['student_class'] == class_id)], x='trial_num',
                    y='total_ex', hue='theta', col='block_type', dodge=True,
                    col_order=['nonSeqFull', 'nonSeqPartial', 'seqNoFeedback', 'seqFeedback'], alpha=0.5)
    (g.set_axis_labels("trial num", "total # examples")
    .set(ylim=(0, 25))
     .set_titles("{col_name}")
     .figure.suptitle(hypers + " total # examples", y=1.1, size=30)
     )
