# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set_theme(style="white", font_scale=1.5)

# %%
data_folder = "../data/2022-05-23_pilot"
df = pd.read_csv(os.path.join(data_folder, 'data_pilot3.csv'), index_col=[0])
df['total_ex'] = df['heads'] + df['tails']
df['mean'] = df['heads'] / (df['heads'] + df['tails'])
df['trial'] = df['block_type'] + df['trial_num'].apply(lambda x: str(x))
df.loc[(df['student_class'] == 'A') | (
    df['student_class'] == 'B'), 'student_experience'] = 'less'
df.loc[(df['student_class'] == 'C') | (
    df['student_class'] == 'D'), 'student_experience'] = 'more'
df['theta'] = df['true_theta'] # for plotting purposes
df
# Out:
#           subject_id  student_idx     block_type  trial_num  true_theta  \
# 0     A107RJSS561Y7R            0    seqFeedback          0         0.2
# 1     A107RJSS561Y7R            0    seqFeedback          1         0.2
# 2     A107RJSS561Y7R            1  seqNoFeedback          0         0.2
# 3     A107RJSS561Y7R            1  seqNoFeedback          1         0.2
# 4     A107RJSS561Y7R            2  nonSeqPartial          0         0.8
# ...              ...          ...            ...        ...         ...
# 4346   AVFMTS8A5R4XK           21  nonSeqPartial          0         0.8
# 4347   AVFMTS8A5R4XK           22    seqFeedback          0         0.5
# 4348   AVFMTS8A5R4XK           22    seqFeedback          1         0.5
# 4349   AVFMTS8A5R4XK           23  seqNoFeedback          0         0.5
# 4350   AVFMTS8A5R4XK           23  seqNoFeedback          1         0.5
#
#       student_a  student_b student_class  heads  tails  student_guess  \
# 0             8          2             D      1      4       0.600000
# 1             8          2             D      1      4       0.500000
# 2             2          8             C      0      5            NaN
# 3             2          8             C      0      5       0.100000
# 4             1          4             A      8      0       0.692308
# ...         ...        ...           ...    ...    ...            ...
# 4346          4          1             B      1      0       0.833333
# 4347          2          8             C      3      2       0.333333
# 4348          2          8             C      3      2       0.400000
# 4349          2          8             C     16     14            NaN
# 4350          2          8             C     12     15       0.447761
#
#          error  bonus  total_bonus understood  total_ex      mean  \
# 0          NaN    NaN         1.31        yes         5  0.200000
# 1     0.300000   0.00         1.31        yes         5  0.200000
# 2          NaN    NaN         1.31        yes         5  0.000000
# 3     0.100000   0.00         1.31        yes         5  0.000000
# 4     0.107692   0.00         1.31        yes         8  1.000000
# ...        ...    ...          ...        ...       ...       ...
# 4346  0.033333   0.49         1.59        yes         1  1.000000
# 4347       NaN    NaN         1.59        yes         5  0.600000
# 4348  0.100000   0.00         1.59        yes         5  0.600000
# 4349       NaN    NaN         1.59        yes        30  0.533333
# 4350  0.052239   0.00         1.59        yes        27  0.444444
#
#                trial student_experience  theta
# 0       seqFeedback0               more    0.2
# 1       seqFeedback1               more    0.2
# 2     seqNoFeedback0               more    0.2
# 3     seqNoFeedback1               more    0.2
# 4     nonSeqPartial0               less    0.8
# ...              ...                ...    ...
# 4346  nonSeqPartial0               less    0.8
# 4347    seqFeedback0               more    0.5
# 4348    seqFeedback1               more    0.5
# 4349  seqNoFeedback0               more    0.5
# 4350  seqNoFeedback1               more    0.5
#
# [4351 rows x 20 columns]

# %%
len(pd.unique(df['subject_id']))
# Out:
# 118

# %% [markdown]
# Exclusion criteria:
# - did not understand instructions
# - bonus less than `$1`

# %%
df = df[(df['understood'] == 'yes') & (df['total_bonus'] > 1)]
len(pd.unique(df['subject_id']))
# Out:
# 103

# %% [markdown]
# Check performance of four different conditions

# %%
f, ax = plt.subplots(figsize=(8, 5))
sns.barplot(data=df, x='block_type', y='bonus')
sns.stripplot(data=df, x='block_type', y='bonus', color='black', alpha=0.1)
ax.set(ylabel='end-of-trial bonus ($)', xlabel='condition')
sns.despine()

# %%
class_hypers = {
    'A': "($a=1$, $b=4$)",
    'B': "($a=4$, $b=1$)",
    'C': "($a=2$, $b=8$)",
    'D': "($a=8$, $b=2$)"
}

for class_id, hypers in class_hypers.items():
    g = sns.catplot(data=df[(df['student_class'] == class_id)], x='trial_num',
                    y='mean', hue='theta', col='block_type', kind='point', dodge=True,
                    col_order=['nonSeqFull', 'nonSeqPartial', 'seqNoFeedback', 'seqFeedback'])
    (g.set_axis_labels("trial num")
     .set_titles("{col_name}")
     .set(ylim=(0, 1))
     .figure.suptitle("data " + hypers + " proportion heads in examples", y=1.1, size=30)
     )


    g = sns.catplot(data=df[(df['student_class'] == class_id)], x='trial_num',
                    y='total_ex', hue='theta', col='block_type', kind='point', dodge=True,
                    col_order=['nonSeqFull', 'nonSeqPartial', 'seqNoFeedback', 'seqFeedback'])
    (g.set_axis_labels("trial num", "total # examples")
    .set(ylim=(0, 25))
     .set_titles("{col_name}")
     .figure.suptitle("data " + hypers + " total # examples", y=1.1, size=30)
     )

# %% [markdown]
# Look at the actual points

# %%
class_hypers = {
    'A': "($a=1$, $b=4$)",
    'B': "($a=4$, $b=1$)",
    'C': "($a=8$, $b=2$)",
    'D': "($a=2$, $b=8$)"
}

for class_id, hypers in class_hypers.items():
    g = sns.catplot(data=df[(df['student_class'] == class_id)], x='trial_num',
                    y='mean', hue='theta', col='block_type', dodge=True,
                    col_order=['nonSeqFull', 'nonSeqPartial', 'seqNoFeedback', 'seqFeedback'], alpha=0.5)
    (g.set_axis_labels("trial num")
     .set_titles("{col_name}")
     .set(ylim=(0, 1.1))
     .figure.suptitle(hypers + " proportion heads in examples", y=1.1, size=30)
     )

    g = sns.catplot(data=df[(df['student_class'] == class_id)], x='trial_num',
                    y='total_ex', hue='theta', col='block_type', dodge=True,
                    col_order=['nonSeqFull', 'nonSeqPartial', 'seqNoFeedback', 'seqFeedback'], alpha=0.5)
    (g.set_axis_labels("trial num", "total # examples")
    .set(ylim=(0, 25))
     .set_titles("{col_name}")
     .figure.suptitle(hypers + " total # examples", y=1.1, size=30)
     )
